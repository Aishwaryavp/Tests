# %%
def test():
  pass

# %%
def test():
  return ("yes")

# %%
def test1():
  print("No")

# %%
test1()
# Out:
# No

# %%
test()
# Out:
# 'yes'

# %%
def test(a,b):
  return (a , b)

# %%
test("Name","Aishwarya")
# Out:
# ('Name', 'Aishwarya')

# %%
print(test("age", 23))
# Out:
# ('age', 23)

# %%
#If not given both parameters a and b
test("Graduated")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_160/209348893.py in <cell line: 0>()
# ----> 1 test("Graduated")
#
# TypeError: test() missing 1 required positional argument: 'b'

# %%
test(a=" Aish", b=23)
# Out:
# (' Aish', 23)

# %%
def square(number):
  return(number*number)

# %%
square(8)
# Out:
# 64

# %%
s =[2, 3, 4]
n=[]
def cube(ls):  # ls in only one argument
  for num in ls:
    n.append(num*num*num)
  return(n)

# %%
cube(s)
# Out:
# [8, 27, 64]

# %%
def name(name):    # name in only one argument
  return(name + " Patil")

# %%
name('Aish')
# Out:
# 'Aish Patil'

# %%
def name(name, age): ## name and age, two arguments
  return(name)

# %%
name("aish", 23)
# Out:
# 'aish'

# %%
type(name)
# Out:
# function

# %%
# bydefault value
def details(name =" Aishwarya", age= 20):    ## name and age, two arguments
  return(name, age)

# %%
details()
# Out:
# (' Aishwarya', 20)

# %%
# overwrite and replace
details("Anju")
# Out:
# ('Anju', 20)

# %%
type(details)
# Out:
# function

# %%
# doc string
def details(name =" Aishwarya", age= 20):           # name and age, two arguments
  "This will provide details of employee"           # this is doc string
  return(name, age)

# %%
# To work with multiple arguments either it can be one arg, two or mutliple arg

def test3(*args):
  return args

# %%
test3(2)
# Out:
# (2,)

# %%
test3(2, 3)
# Out:
# (2, 3)

# %%
test3(2,(3), 3)
# Out:
# (2, 3, 3)

# %%
test3(2, 3, "atr", 4 , 4, 5 , 7)
# Out:
# (2, 3, 'atr', 4, 4, 5, 7)

# %%
test3(2, 3, [4,5])
# Out:
# (2, 3, [4, 5])

# %%
def test4(*args, name= "Aishwarya"):
  return args, name

# %%
test4(2, 3, [4,5])
# Out:
# ((2, 3, [4, 5]), 'Aishwarya')

# %%
def test5(*args, name):
  return args, name

# %%
test5(2, 3, [4,5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_160/731136725.py in <cell line: 0>()
# ----> 1 test5(2, 3, [4,5])
#
# TypeError: test5() missing 1 required keyword-only argument: 'name'

# %%
test5((2, 3, [4,5]), "aish")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_160/1290082736.py in <cell line: 0>()
# ----> 1 test5((2, 3, [4,5]), "aish")
#
# TypeError: test5() missing 1 required keyword-only argument: 'name'

# %%
test5((2, 3, [4,5]),name= "aish") #when args, it understand evry parameter as args only, so need to mention variable name here
# Out:
# (((2, 3, [4, 5]),), 'aish')

# %%
#kwagrs for key- value pair (dict)
def test6(**kwargs):
  return kwargs

# %%
test6(a=1)
# Out:
# {'a': 1}

# %%
test6(a=1 , b=2)
# Out:
# {'a': 1, 'b': 2}

# %%
def test7(**aish):
  return aish

# %%
test7(a=1)
# Out:
# {'a': 1}

# %%
def ddict(**a):
  return a

# %%
ddict(a=3)
# Out:
# {'a': 3}

# %%
#lambda - for creating anonymous function
n= lambda a,b : a*b

# %%
n(4,5)
# Out:
# 20

# %%
m= n(2,2)
m
# Out:
# 4

# %%
dd= lambda **kwargs: kwargs

# %%
dd(e=3) #compulsory give as key and value
# Out:
# {'e': 3}

# %%
e= dd(e=3,f=5,k ="king")
e
# Out:
# {'e': 3, 'f': 5, 'k': 'king'}

# %%
r= lambda *args: args
r(1)
# Out:
# (1,)

# %%
r(2,3,4,"king")
# Out:
# (2, 3, 4, 'king')

# %%
#square
add = lambda a:a*a
add(4)
# Out:
# 16

# %%
#eevn
evn= lambda b: b%2==0
evn(2)
# Out:
# True

# %%
mult= lambda a,b : a*b
mult(2,3)
# Out:
# 6

# %%
div = lambda a,b: a//b if a>b else b//a
div(4,1)
# Out:
# 4

# %%
div(5,10)
# Out:
# 2

# %%
div(10,2)
# Out:
# 5

# %%
#get even
lis=[1,2,3,4,5,6]
ev_lis= list(filter((lambda a: a%2 ==0),lis))
ev_lis
# Out:
# [2, 4, 6]
